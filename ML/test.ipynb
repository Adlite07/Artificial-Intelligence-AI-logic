# %%
import joblib

# %%
DTC = joblib.load('../model/decision_tree.pk1')

# %%
DTC.predict([[5, 80, 3]])
# Out:
# c:\Users\adlit\OneDrive\Desktop\cab315_\D38\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['B'], dtype=object)
