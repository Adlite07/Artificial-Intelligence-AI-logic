# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("../data/student_performance_200_rows.csv")

# %%
#data preprocessing
data.sample()
# Out:
#      Study_Hours  Attendance_Percentage  Assignments_Completed Final_Grade
# 198            7                     84                      9           A

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Study_Hours            200 non-null    int64
#  1   Attendance_Percentage  200 non-null    int64
#  2   Assignments_Completed  200 non-null    int64
#  3   Final_Grade            200 non-null    str
# dtypes: int64(3), str(1)
# memory usage: 6.4 KB

# %%
data.duplicated().sum()
# Out:
# np.int64(1)

# %%
data.drop_duplicates(inplace = True)

# %%
data.columns
# Out:
# Index(['Study_Hours', 'Attendance_Percentage', 'Assignments_Completed',
#        'Final_Grade'],
#       dtype='str')

# %%
data['Study_Hours']
# Out:
# 0      2
# 1      4
# 2      2
# 3      2
# 4      1
#       ..
# 195    1
# 196    7
# 197    6
# 198    7
# 199    4
# Name: Study_Hours, Length: 199, dtype: int64

# %%
#EDA univariate analysis
plt.hist(x = data['Study_Hours'], bins = 10)
plt.show()

# %%
#bivariate analysis
plt.scatter(data['Study_Hours'], data['Final_Grade'])

# %%
#bivariate analysis
plt.scatter(data['Attendance_Percentage'], data['Final_Grade'])

# %%
X = data.iloc[:,[0,1,2]]
X
Y = data['Final_Grade']

# %%
#decision tree
from sklearn.tree import DecisionTreeClassifier
DTC = DecisionTreeClassifier()

# %%
DTC.fit(X,Y)
# Out:
# DecisionTreeClassifier()

# %%
DTC.predict(X)
# Out:
# array(['C', 'B', 'B', 'B', 'D', 'B', 'C', 'A', 'B', 'A', 'B', 'C', 'C',
#        'B', 'C', 'A', 'A', 'C', 'B', 'C', 'A', 'B', 'B', 'C', 'B', 'A',
#        'A', 'D', 'A', 'B', 'A', 'A', 'C', 'A', 'A', 'A', 'B', 'A', 'C',
#        'A', 'A', 'A', 'C', 'A', 'C', 'C', 'B', 'B', 'B', 'B', 'C', 'A',
#        'A', 'C', 'C', 'B', 'B', 'B', 'A', 'A', 'A', 'A', 'C', 'C', 'B',
#        'D', 'C', 'A', 'B', 'B', 'A', 'A', 'B', 'A', 'A', 'C', 'B', 'B',
#        'A', 'B', 'B', 'C', 'D', 'B', 'A', 'C', 'C', 'A', 'A', 'B', 'C',
#        'C', 'A', 'B', 'C', 'B', 'A', 'A', 'C', 'A', 'A', 'A', 'A', 'A',
#        'B', 'C', 'B', 'C', 'B', 'B', 'A', 'B', 'B', 'C', 'B', 'B', 'A',
#        'B', 'A', 'B', 'C', 'A', 'A', 'A', 'C', 'B', 'C', 'C', 'C', 'B',
#        'A', 'A', 'B', 'A', 'A', 'B', 'C', 'A', 'A', 'C', 'B', 'B', 'A',
#        'A', 'B', 'A', 'B', 'A', 'A', 'B', 'C', 'A', 'B', 'B', 'A', 'A',
#        'A', 'B', 'B', 'A', 'A', 'C', 'A', 'A', 'A', 'A', 'B', 'B', 'B',
# ...

# %%
DTC.score(X,Y)
# Out:
# 1.0

# %%
#creates a model
import joblib
joblib.dump(DTC, 'decision_tree.pk1')
# Out:
# ['decision_tree.pk1']
