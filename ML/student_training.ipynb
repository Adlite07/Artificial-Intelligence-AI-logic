# %%
import opendatasets as od

# %%
od.download("https://www.kaggle.com/datasets/adlitemutambara/student-performance-data")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:Your Kaggle Key:Dataset URL: https://www.kaggle.com/datasets/adlitemutambara/student-performance-data
# ...
# 100%|██████████| 980/980 [00:00<00:00, 706kB/s]
